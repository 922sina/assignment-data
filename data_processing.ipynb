# %% [markdown]
# <a href="https://colab.research.google.com/github/922sina/assignment-data/blob/main/data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import edvart

# %%
school_data = pd.read_csv("/content/AssignmentW1/student_grades.csv")

# %%
print("school_data")
# Out:
# school_data

# %%
school_data.head()

# %%
data =np.genfromtxt("/content/AssignmentW1/student_grades.csv", delimiter=',' ,dtype=None, encoding=None)

# %%
data =np.array([75,80,60])

# %%
std_dev =np.std(data)

# %%
print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 8.498365855987975

# %%
report = edvart.DefaultReport(school)
# Show the report in the current Jupyter notebook
report.export_notebook("report.ipynb")
report.show()
# Out:
# # Table of Contents
# ---
#  * [Overview](#1e7ab6f6-ef13-445a-98c0-ff8f03f2aa88)
#
# 	 * [Quick Info](#3b95d1b8-26ab-4f59-b852-476d973dc8fd)
#
# 	 * [Data Types](#dffb5e5d-aee5-4220-b49d-054df2b8ecf9)
#
# 	 * [Data Preview](#189c6623-8937-40ac-9467-c6b8c3549799)
#
# 	 * [Missing Values](#d7863657-fa5e-44e1-9977-948fda983e72)
#
# 	 * [Rows With Missing Value](#79730193-0589-4585-858f-085ebccbaaa7)
#
# 	 * [Constant Occurrence](#0ee068ca-686b-46a5-b50b-3ed7a451b337)
#
# 	 * [Duplicate Rows](#dbf44c8d-1fff-49ca-bb5e-100670900dbc)
#
#  * [Univariate Analysis](#870fdcdb-72cf-4582-a0cc-86c8b3087c39)
#
#  * [Bivariate analysis](#67a198b5-ae82-41c4-9861-78ddd6cb9104)
#
# 	 * [Correlation Plot](#c1787d21-8653-42b9-8896-31e48f2dc028)
#
# 	 * [Pairplot](#393f1a45-0b4e-4288-99f9-13377f480258)
#
# 	 * [Contingency table](#5162ee00-c4dc-48aa-ac1b-ef515e6db3af)
#
#  * [Multivariate analysis](#3ee32eae-8b6e-40db-b0e9-4a2cd71b3b7d)
#
# ...
